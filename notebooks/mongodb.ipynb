# %% [markdown]
# #### Client -> database -> collection -> store data

# %%
import pymongo
from pymongo import MongoClient

# %%
connection_string = "mongodb+srv://armaanirani:<password>@cluster0.zlzpoz7.mongodb.net/?appName=Cluster0"

# %%
client = MongoClient(connection_string)

# %%
db = client["apssensor"]

# %%
collection = db["mongoclass"]

# %%
data = {
    "name": "armaan irani",
    "age": 25,
    "email": "asd@gmail.com"
}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('6969bf243b1e3db2b4dd5ddf'), acknowledged=True)

# %%
# to fetch the data
cursor = collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('6969bf243b1e3db2b4dd5ddf'), 'name': 'armaan irani', 'age': 25, 'email': 'asd@gmail.com'}
